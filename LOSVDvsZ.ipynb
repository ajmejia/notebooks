# %%
# %pylab inline

import pres_style, os
from itertools import product
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
list1 = sorted([os.path.join(root, file) for root, subs, files in os.walk(os.path.expandvars("test_c1_c2/av0_1_4Z")) for file in files if file.startswith("dynbasfit_processed_")])
list2 = sorted([os.path.join(root, file) for root, subs, files in os.walk(os.path.expandvars("test_c1_c2/av0_1_wm32")) for file in files if file.startswith("dynbasfit_processed_")])
list3 = sorted([os.path.join(root, file) for root, subs, files in os.walk(os.path.expandvars("test_c1_c2/av0_1_4Z_CaIIHK")) for file in files if file.startswith("dynbasfit_processed_")])

C1_table = genfromtxt("C1_table.txt", dtype=None, names=True)
C2_table = genfromtxt("C2_table.txt", dtype=None, names=True)

t1 = genfromtxt(os.path.expandvars("test_c1_c2/av0_1_4Z/dynbas_output.log"), dtype=None, names=True)
t2 = genfromtxt(os.path.expandvars("test_c1_c2/av0_1_wm32/dynbas_output.log"), dtype=None, names=True)
t3 = genfromtxt(os.path.expandvars("test_c1_c2/av0_1_4Z_CaIIHK/dynbas_output.log"), dtype=None, names=True)

C1 = loadtxt("test_c1_c2/SEDs/C1.txt", dtype=str)
C2 = loadtxt("test_c1_c2/SEDs/C2.txt", dtype=str)

m22 = loadtxt("m22.txt")
m32 = loadtxt("m32.txt")
m42 = loadtxt("m42.txt")
m52 = loadtxt("m52.txt")
m62 = loadtxt("m62.txt")
m72 = loadtxt("m72.txt")

ages = array([1.015E+08,  1.015E+09,  3.000E+09,  1.000E+10])/1e9
mets = array([0.0001, 0.0004, 0.004, 0.008, 0.02, 0.05])/0.02
mods = [m22, m32, m42, m52, m62, m72]
wlrs = [(390, 400), (515, 520), (840, 870)]

# %%
fig, axs = subplots(len(mods), len(wlrs), figsize=(10, 15), sharex="col", sharey=True)

ylim(1e-7, 1)

axs[-1, 1].set_xlabel("Wavelength (nm)")

for i, j in product(xrange(axs.shape[0]), xrange(axs.shape[1])):
    ls = axs[i, j].semilogy(mods[i][:, 0]/10., mods[i][:, 1:], "-", lw=1)
    axs[i, j].set_xlim(wlrs[j])
    
    if j == 0: axs[i, j].set_ylabel("Flux")
    if j == len(wlrs)-1:
        axs[i, j].yaxis.set_label_position("right")
        axs[i, j].set_ylabel("{0}Zsun".format(mets[i]), size="x-small")
        
axs[0, 0].legend(ls, map(lambda t: "{0:.1f}Gyr".format(t), ages), loc=0, fontsize=10, ncol=2)

fig.tight_layout()

# %%
slist = list3

fig, axs = subplots(len(slist), len(wlrs), figsize=(10, 35), sharex="col", sharey=True)

ylim(1e4, 1e7)

axs[-1, 1].set_xlabel("Wavelength (nm)")

for i, j in product(xrange(len(slist)), xrange(len(wlrs))):
    sname = slist[i].split("/")[-1].lstrip("dynbasfit_").replace(".log", ".txt")
    wl, fl, sg, m3 = loadtxt(slist[i], usecols=(0,1,2,5), unpack=True)
    wl /= 10.
    mask = (wl>=wlrs[j][0])&(wl<=wlrs[j][1])&(fl>0.0)
    axs[i, j].semilogy(wl[mask], fl[mask], "-", color="0.2", lw=1.5, label="SNR={0:.1f}".format(median(fl[mask]/sg[mask])))
    axs[i, j].semilogy(wl[mask], m3[mask], "-", lw=1.5, label="DynBaS3D")
    axs[i, j].set_xlim(wlrs[j])
    axs[i, j].legend(loc=0, fontsize=10)
    
    if j == 0: axs[i, j].set_ylabel("Flux")
    if j == len(wlrs)-1:
        axs[i, j].yaxis.set_label_position("right")
        axs[i, j].set_ylabel("C2" if sname in C2 else "C1")

fig.tight_layout()

# %%
plot(t1["lw_logage"], t1["lw_logz_zo"], "o", label="prueba #1")
plot(t2["lw_logage"], t2["lw_logz_zo"], "o", label="prueba #2")
plot(t3["lw_logage"], t3["lw_logz_zo"], "o", label="prueba #3")

plot(C1_table["log_t_L_mod"], C1_table["log_Z_L_mod"], "x", color="k", mew=2, label="orig,C1")
plot(C2_table["log_t_L_mod"], C2_table["log_Z_L_mod"], "+", color="k", mew=2, label="orig,C2")

legend(loc=2, fontsize=10)

xlim(8.0, 10.2)
ylim(-0.7, 0.4)
# Out:
# (-0.7, 0.4)
