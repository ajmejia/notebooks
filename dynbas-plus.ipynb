# %%
# %pylab inline

from tools.stats import err, binner
from styles import slides
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ngal = 120

dp = loadtxt("../outputs/dynbas+/dynbas3_nd_4SSPs_SNR80.all", usecols=(3,6,7,8,9,1))[:ngal*7]
tg = loadtxt("../outputs/dynbas+/tgaspex_nd_4SSPs_SNR80.all", usecols=(3,6,7,8,9,1))[:ngal*7]
ep = loadtxt("../outputs/dynbas+/dynbas3_nd_4SSPs_SNR80.all", usecols=(10,))[:ngal*7]
np = loadtxt("../outputs/dynbas+/tgaspex_nd_4SSPs_SNR80.all", usecols=(4,))[:ngal*7]

dp[:, 0] /=1e6
tg[:, 0] /=1e6

tp = []
for i in xrange(ngal):
    tp.append(loadtxt("../inputs/tta_bc03/set_bc03/stelib/SSAG3{0:03d}_z0p00nd.tparam".format(i+1), usecols=(7,16,19,1,1,8)))

tp = array(tp)
tp[:, 3:5] = log10(tp[:, 3:5])
rl = [True]+5*[False]
cp = map(str, ep[:7])
kw = "M log_t_M log_t_L log_Z_M log_Z_L Av".split()
lb = r"$M$", r"$\log{t}_M$", r"$\log{t}_L$", r"$\log{Z}_M$", r"$\log{Z}_L$", r"$A_V$"

# %%
step=0.3

for j in xrange(len(lb)-1):
    fig, (axd, axg) = subplots(1, 2, sharey=True, figsize=(10, 5))
    for i in xrange(7):
        axd.set_title("DynBaS+")
        axg.set_title("TGaspex")
        axd.plot(tp[:, j], err(tp[:, j], dp[i::7, j], rl[j])+i*step, ".", ms=4, label=cp[i])
        axg.plot(tp[:, j], err(tp[:, j], tg[i::7, j], rl[j])+i*step, ".", ms=4)
        axd.axhline(i*step, ls="--", color="0.2", lw=0.5)
        axg.axhline(i*step, ls="--", color="0.2", lw=0.5)

    axd.legend(loc=8, title="eps", ncol=7, fontsize=8, handletextpad=0.01)
    axd.set_yticks([i*step for i in xrange(7)])
    axd.set_yticklabels([0.0]*7)

    axd.set_xlabel("True "+lb[j])
    axg.set_xlabel("True "+lb[j])
    axd.set_ylabel("Delta "+lb[j])
    fig.tight_layout()
    
    savefig("img/residuals_vs_true_"+kw[j], bbox_inches="tight")

# %%
step=0.3
eps = 6
for j in xrange(len(lb)-1):
    fig, (axd, axg) = subplots(1, 2, sharey=True, figsize=(10, 5))
    for i in xrange(7):
        axd.set_title("DynBaS+")
        axg.set_title("TGaspex")
        axd.plot(dp[eps::7, j], err(dp[eps::7, j], dp[i::7, j], rl[j])+i*step, ".", ms=4, label=cp[i])
        axg.plot(tg[eps::7, j], err(tg[eps::7, j], tg[i::7, j], rl[j])+i*step, ".", ms=4, label=cp[i])
        axd.axhline(i*step, ls="--", color="0.2", lw=0.5)
        axg.axhline(i*step, ls="--", color="0.2", lw=0.5)

    axd.legend(loc=8, title="eps", ncol=7, fontsize=8, handletextpad=0.01)
    axd.set_yticks([i*step for i in xrange(7)])
    axd.set_yticklabels([0.0]*7)

    axd.set_xlabel(lb[j]+" (eps={})".format(ep[:7][eps]))
    axg.set_xlabel(lb[j]+" (eps={})".format(ep[:7][eps]))
    axd.set_ylabel("Delta(eps={}) ".format(ep[:7][eps])+lb[j])
    fig.tight_layout()
    
    savefig("img/diff_eps_vs_eps_"+kw[j], bbox_inches="tight")

# %%
for j in xrange(len(lb)-1):
    fig, (axd, axg) = subplots(1, 2, sharey=True, figsize=(10, 5))
    axd.set_title("DynBaS+")
    axg.set_title("TGaspex")
    axd.hist([dp[i::7, j] for i in xrange(7)], 10, range=(tp[:, j].min(), tp[:, j].max()), histtype="barstacked", lw=0, label=cp, alpha=0.7)
    axd.hist(repeat(tp[:, j], 7, axis=0), 10, range=(tp[:, j].min(), tp[:, j].max()), histtype="step", lw=1, color="0.2", label="True")
    axg.hist([tg[i::7, j] for i in xrange(7)], 10, range=(tp[:, j].min(), tp[:, j].max()), histtype="barstacked", lw=0, label=cp, alpha=0.7)
    axg.hist(repeat(tp[:, j], 7, axis=0), 10, range=(tp[:, j].min(), tp[:, j].max()), histtype="step", lw=1, color="0.2", label="True")
    
    axd.set_xlabel(lb[j])
    axg.set_xlabel(lb[j])
    axd.set_ylabel("counts")
    axd.legend(loc=0)
    fig.tight_layout()
    
    savefig("img/dist_"+kw[j], bbox_inches="tight")
